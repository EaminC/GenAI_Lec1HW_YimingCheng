# %%
from IPython.display import HTML, display

def set_css(*args, **kwargs):  
    display(HTML('''
    <style>
        pre {
            white-space: pre-wrap;
        }
    </style>
    '''))

get_ipython().events.register('pre_run_cell', set_css)

# %%
import sys
# !{sys.executable} -m pip install openai
# Out:
# Error in callback <function set_css at 0x1072d49d0> (for pre_run_cell), with arguments args (<ExecutionInfo object at 111e4c340, raw_cell="import sys
# !{sys.executable} -m pip install openai" store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/eamin/Desktop/data/%E5%AD%A6%E4%B9%A0%E8%B5%84%E6%96%99/2025_spring/GenAI/Lec1/Lec1_HW_YimingCheng_124505888/HW1-1/hello_gpt4o.ipynb#X14sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: set_css() takes 0 positional arguments but 1 was given
# Error in callback <function set_css at 0x111eb4e50> (for pre_run_cell), with arguments args (<ExecutionInfo object at 111e4c340, raw_cell="import sys
# ...

# %%
import os
import sys
import openai
import textwrap
from google.colab import userdata

# %% [markdown]
# The following is how to make a secret into an environment variable on Google Colab. Your setup may work differently

# %%
from google.colab import userdata
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# %%
client = openai.OpenAI()

# %%
completion = client.chat.completions.create(
  model="gpt-4o",
  temperature = 0.2,
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Tell me the story of the frog and scorpion briefly"}
  ]
)

# %%
print(completion)

# %%
print(completion.choices[0].message.content)
